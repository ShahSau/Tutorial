# %%
x= [1,2,3,4,5,6,7,8,9]
y=[1,2,3,4,5,6,7,8,9]
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.show()

# %%
x= [1,2,3,4,5,6,7,8,9]
y=[1,2,3,4,5,6,7,8,9]
import matplotlib.pyplot as plt
plt.plot(x,y,color="r",marker="v",linestyle="--")
plt.show()
